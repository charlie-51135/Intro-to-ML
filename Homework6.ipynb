# %% [markdown]
# <a href="https://colab.research.google.com/github/charlie-51135/Intro-to-ML/blob/main/Homework6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt
from google.colab import drive
from sklearn.preprocessing import StandardScaler
drive.mount('/content/drive')
torch.set_printoptions(edgeitems=2, linewidth=75)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Problem 1: SGD**

# %%
def training_loop_val(n_epochs, optimizer, model, loss_fn, X_train, y_train, X_val, y_val):
    train_losses = []
    val_losses = []
    for epoch in range(1, n_epochs + 1):
        train_y_pred = model(X_train)
        train_loss = loss_fn(train_y_pred, y_train)
        train_losses.append(train_loss.item())

        val_y_pred = model(X_val)
        val_loss = loss_fn(val_y_pred, y_val)
        val_losses.append(val_loss.item())

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

        if epoch % 500 == 0:
            print(f'Epoch {epoch}, \tTrain Loss {train_loss:.1f}, \tVal Loss {val_loss:.1f}')

    return train_losses, val_losses

file_path = '/content/drive/MyDrive/Intro-to-ML/Housing.csv'
housing = pd.read_csv(file_path)
# Check for null values
#housing.isnull().sum()*100/housing.shape[0]

# Replace yes/no data
varlist =  ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea']
housing[varlist] = housing[varlist].apply(lambda x: x.map({'yes': 1, 'no': 0}))

# Split training and test data
input_vars = ['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefarea']
y = housing.pop('price')
X = housing[input_vars]

# Apply standardization
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Convert to tensors
X_tensor = torch.tensor(X_std, dtype=torch.float32)
y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)

# Split training and test data
torch.manual_seed(123)
n_samples = X_tensor.shape[0]
n_val = int(n_samples * 0.2)
shuffled_indices = torch.randperm(n_samples)

train_indices = shuffled_indices[:-n_val]
val_indices = shuffled_indices[-n_val:]

X_train = X_tensor[train_indices]
y_train = y_tensor[train_indices]

X_val = X_tensor[val_indices]
y_val = y_tensor[val_indices]

# %% [markdown]
# # **Problem 1a: 11 features, SGD, one hidden layer**

# %%
for learning_rate in [0.01, 0.001, 0.0001]:
    torch.manual_seed(123)
    print(f'\nLearning rate = {learning_rate}\n')

    seq_model = nn.Sequential(
                nn.Linear(11, 32),
                nn.Tanh(),
                nn.Linear(32, 1))
    optimizer = optim.SGD(seq_model.parameters(), lr=learning_rate)

    train_losses, val_losses = training_loop_val(
        n_epochs = 5000,
        optimizer = optimizer,
        model = seq_model,
        loss_fn = nn.MSELoss(),
        X_train = X_train,
        y_train = y_train,
        X_val = X_val,
        y_val = y_val)
    # print(f'\nParams = {trained_model}\n')

    plt.figure(figsize=(10, 6))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.title(f'Training and Validation Loss Over Epochs, lr = {learning_rate}')
    plt.legend()
    plt.show()
# Out:
# Learning rate = 0.01
#
# Epoch 500, 	Train Loss 1748731953152.0, 	Val Loss 1337873399808.0
# Epoch 1000, 	Train Loss 1729784709120.0, 	Val Loss 1319198654464.0
# Epoch 1500, 	Train Loss 1721985531904.0, 	Val Loss 1308622716928.0
# Epoch 2000, 	Train Loss 1717005713408.0, 	Val Loss 1301727150080.0
# Epoch 2500, 	Train Loss 1713369513984.0, 	Val Loss 1297198481408.0
# Epoch 3000, 	Train Loss 1710577549312.0, 	Val Loss 1294235074560.0
# Epoch 3500, 	Train Loss 1708369510400.0, 	Val Loss 1292324175872.0
# Epoch 4000, 	Train Loss 1706582081536.0, 	Val Loss 1291133386752.0
# Epoch 4500, 	Train Loss 1705106341888.0, 	Val Loss 1290442768384.0
# Epoch 5000, 	Train Loss 1703866007552.0, 	Val Loss 1290103685120.0
# Learning rate = 0.001
#
# Epoch 500, 	Train Loss 1934368964608.0, 	Val Loss 1673174450176.0
# Epoch 1000, 	Train Loss 1680379346944.0, 	Val Loss 1481561735168.0
# Epoch 1500, 	Train Loss 1585454252032.0, 	Val Loss 1429978611712.0
# Epoch 2000, 	Train Loss 1544219262976.0, 	Val Loss 1418871439360.0
# Epoch 2500, 	Train Loss 1524143095808.0, 	Val Loss 1419809914880.0
# Epoch 3000, 	Train Loss 1513315237888.0, 	Val Loss 1423880486912.0
# Epoch 3500, 	Train Loss 1506907652096.0, 	Val Loss 1428284112896.0
# Epoch 4000, 	Train Loss 1502796972032.0, 	Val Loss 1432224792576.0
# Epoch 4500, 	Train Loss 1499976957952.0, 	Val Loss 1435556511744.0
# Epoch 5000, 	Train Loss 1497934331904.0, 	Val Loss 1438326718464.0
# Learning rate = 0.0001
#
# Epoch 500, 	Train Loss 14626354888704.0, 	Val Loss 13996186927104.0
# Epoch 1000, 	Train Loss 9029188321280.0, 	Val Loss 8743623327744.0
# Epoch 1500, 	Train Loss 6283755782144.0, 	Val Loss 6127484928000.0
# Epoch 2000, 	Train Loss 4873561047040.0, 	Val Loss 4748120948736.0
# Epoch 2500, 	Train Loss 4100694212608.0, 	Val Loss 3967400542208.0
# Epoch 3000, 	Train Loss 3639200710656.0, 	Val Loss 3486247550976.0
# Epoch 3500, 	Train Loss 3335331512320.0, 	Val Loss 3161837273088.0
# Epoch 4000, 	Train Loss 3115560730624.0, 	Val Loss 2924468502528.0
# Epoch 4500, 	Train Loss 2943997706240.0, 	Val Loss 2739139510272.0
# Epoch 5000, 	Train Loss 2802550833152.0, 	Val Loss 2587551072256.0

# %% [markdown]
# # **Problem 1b: 11 features, SGD, three hidden layers**

# %%
for learning_rate in [0.01, 0.001, 0.0001]:
    torch.manual_seed(123)
    print(f'\nLearning rate = {learning_rate}\n')

    seq_model = nn.Sequential(
                nn.Linear(11, 32),
                nn.Tanh(),
                nn.Linear(32, 64),
                nn.Tanh(),
                nn.Linear(64, 16),
                nn.Tanh(),
                nn.Linear(16, 1))
    optimizer = optim.SGD(seq_model.parameters(), lr=learning_rate)

    train_losses, val_losses = training_loop_val(
        n_epochs = 5000,
        optimizer = optimizer,
        model = seq_model,
        loss_fn = nn.MSELoss(),
        X_train = X_train,
        y_train = y_train,
        X_val = X_val,
        y_val = y_val)
    # print(f'\nParams = {trained_model}\n')

    plt.figure(figsize=(10, 6))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    # plt.title(f'Training and Validation Loss Over Epochs, lr = {learning_rate}')
    plt.legend()
    plt.show()
# Out:
# Learning rate = 0.01
#
# Epoch 500, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Epoch 1000, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Epoch 1500, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Epoch 2000, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Epoch 2500, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Epoch 3000, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Epoch 3500, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Epoch 4000, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Epoch 4500, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Epoch 5000, 	Train Loss 3549377069056.0, 	Val Loss 3265555595264.0
# Learning rate = 0.001
#
# Epoch 500, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 1000, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 1500, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 2000, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 2500, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 3000, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 3500, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 4000, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 4500, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 5000, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Learning rate = 0.0001
#
# Epoch 500, 	Train Loss 4320431964160.0, 	Val Loss 3842717515776.0
# Epoch 1000, 	Train Loss 3574961274880.0, 	Val Loss 3255821139968.0
# Epoch 1500, 	Train Loss 3550225629184.0, 	Val Loss 3259970879488.0
# Epoch 2000, 	Train Loss 3549404856320.0, 	Val Loss 3264411860992.0
# Epoch 2500, 	Train Loss 3549377593344.0, 	Val Loss 3265342472192.0
# Epoch 3000, 	Train Loss 3549376806912.0, 	Val Loss 3265514176512.0
# Epoch 3500, 	Train Loss 3549377069056.0, 	Val Loss 3265538555904.0
# Epoch 4000, 	Train Loss 3549377069056.0, 	Val Loss 3265538555904.0
# Epoch 4500, 	Train Loss 3549377069056.0, 	Val Loss 3265538555904.0
# Epoch 5000, 	Train Loss 3549377069056.0, 	Val Loss 3265538555904.0

# %%
for learning_rate in [1000]:
    print(f'\nLearning rate = {learning_rate}\n')

    seq_model = nn.Sequential(
                nn.Linear(11, 32),
                nn.Tanh(),
                nn.Linear(32, 64),
                nn.Tanh(),
                nn.Linear(64, 16),
                nn.Tanh(),
                nn.Linear(16, 1))
    optimizer = optim.Adam(seq_model.parameters(), lr=learning_rate)

    train_losses, val_losses = training_loop_val(
        n_epochs = 5000,
        optimizer = optimizer,
        model = seq_model,
        loss_fn = nn.MSELoss(),
        X_train = X_train,
        y_train = y_train,
        X_val = X_val,
        y_val = y_val)
    # print(f'\nParams = {trained_model}\n')

    plt.figure(figsize=(10, 6))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.title(f'Training and Validation Loss Over Epochs, lr = {learning_rate}')
    plt.legend()
    plt.show()
# Out:
# Learning rate = 1000
#
# Epoch 500, 	Train Loss 3605391736832.0, 	Val Loss 3269310283776.0
# Epoch 1000, 	Train Loss 3549377331200.0, 	Val Loss 3265428979712.0
# Epoch 1500, 	Train Loss 3549376806912.0, 	Val Loss 3265552973824.0
# Epoch 2000, 	Train Loss 3549376806912.0, 	Val Loss 3265553235968.0
# Epoch 2500, 	Train Loss 3549376806912.0, 	Val Loss 3265553760256.0
# Epoch 3000, 	Train Loss 3549376806912.0, 	Val Loss 3265554284544.0
# Epoch 3500, 	Train Loss 3549376806912.0, 	Val Loss 3265554284544.0
# Epoch 4000, 	Train Loss 3549377069056.0, 	Val Loss 3265554808832.0
# Epoch 4500, 	Train Loss 3549377069056.0, 	Val Loss 3265554808832.0
# Epoch 5000, 	Train Loss 3549377069056.0, 	Val Loss 3265555070976.0

# %% [markdown]
# # **Problem 2a: 10 classes in CIFAR-10, SGD, one hidden layer**

# %%
from matplotlib import pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms

print(torch.cuda.is_available())
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.set_printoptions(edgeitems=2)
torch.manual_seed(123)

cifar10 = datasets.CIFAR10('data', train=True, download=True,
                          transform=transforms.ToTensor())
# Out:
# False
# Files already downloaded and verified

# %%
imgs = torch.stack([img for img, _ in cifar10], dim=3)
print(imgs.shape)
print(imgs.view(3, -1).mean(dim=1))
print(imgs.view(3, -1).std(dim=1))
# Out:
# torch.Size([3, 32, 32, 50000])
# tensor([0.4914, 0.4822, 0.4465])
# tensor([0.2470, 0.2435, 0.2616])

# %%
cifar10 = datasets.CIFAR10('data', train=True, download=True,
                          transform=transforms.Compose([
                              transforms.ToTensor(),
                              transforms.Normalize((0.4914, 0.4822, 0.4465),
                                                   (0.2470, 0.2435, 0.2616))
                          ]))
cifar10_val = datasets.CIFAR10('data', train=False, download=True,
                          transform=transforms.Compose([
                              transforms.ToTensor(),
                              transforms.Normalize((0.4914, 0.4822, 0.4465),
                                                   (0.2470, 0.2435, 0.2616))
                          ]))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64, shuffle=True)

model = nn.Sequential(
            nn.Linear(3072, 512),
            nn.Tanh(),
            nn.Linear(512, 10),
            nn.LogSoftmax(dim=1)
          ).to(device)

learning_rate = 1e-2
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
loss_fn = nn.NLLLoss()
n_epochs = 100

for epoch in range(n_epochs):
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        loss = loss_fn(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print("Epoch: %d, Loss: %f" % (epoch, float(loss)))
# Out:
# Epoch: 0, Loss: 1.839323
# Epoch: 1, Loss: 1.377355
# Epoch: 2, Loss: 1.992598
# Epoch: 3, Loss: 1.299120
# Epoch: 4, Loss: 1.646955
# Epoch: 5, Loss: 1.176936
# Epoch: 6, Loss: 1.235960
# Epoch: 7, Loss: 1.330975
# Epoch: 8, Loss: 2.059361
# Epoch: 9, Loss: 1.038097
# Epoch: 10, Loss: 1.232020
# Epoch: 11, Loss: 1.329082
# Epoch: 12, Loss: 1.225337
# Epoch: 13, Loss: 1.484698
# Epoch: 14, Loss: 0.892012
# Epoch: 15, Loss: 1.168450
# Epoch: 16, Loss: 1.121411
# Epoch: 17, Loss: 1.353362
# Epoch: 18, Loss: 0.667474
# Epoch: 19, Loss: 1.156046
# Epoch: 20, Loss: 1.208070
# Epoch: 21, Loss: 1.132026
# Epoch: 22, Loss: 1.019706
# Epoch: 23, Loss: 0.985610
# Epoch: 24, Loss: 0.931053
# Epoch: 25, Loss: 1.080420
# Epoch: 26, Loss: 0.973217
# Epoch: 27, Loss: 0.696446
# Epoch: 28, Loss: 0.756412
# Epoch: 29, Loss: 0.754965
# Epoch: 30, Loss: 1.074164
# Epoch: 31, Loss: 0.661706
# Epoch: 32, Loss: 0.647972
# Epoch: 33, Loss: 0.703471
# Epoch: 34, Loss: 0.493582
# Epoch: 35, Loss: 0.350279
# Epoch: 36, Loss: 0.573065
# Epoch: 37, Loss: 0.558999
# Epoch: 38, Loss: 0.643272
# Epoch: 39, Loss: 0.435602
# Epoch: 40, Loss: 0.508653
# Epoch: 41, Loss: 0.549883
# Epoch: 42, Loss: 0.704689
# Epoch: 43, Loss: 0.302747
# Epoch: 44, Loss: 0.550846
# Epoch: 45, Loss: 0.351916
# Epoch: 46, Loss: 0.446851
# Epoch: 47, Loss: 0.246359
# Epoch: 48, Loss: 0.383122
# Epoch: 49, Loss: 0.264769
# Epoch: 50, Loss: 0.221475
# Epoch: 51, Loss: 0.169580
# Epoch: 52, Loss: 0.147869
# Epoch: 53, Loss: 0.091069
# Epoch: 54, Loss: 0.360525
# Epoch: 55, Loss: 0.255648
# Epoch: 56, Loss: 0.329627
# Epoch: 57, Loss: 0.260014
# Epoch: 58, Loss: 0.096653
# Epoch: 59, Loss: 0.124436
# Epoch: 60, Loss: 0.279079
# Epoch: 61, Loss: 0.206434
# Epoch: 62, Loss: 0.317445
# Epoch: 63, Loss: 0.114144
# Epoch: 64, Loss: 0.138703
# Epoch: 65, Loss: 0.057206
# Epoch: 66, Loss: 0.040890
# Epoch: 67, Loss: 0.112631
# Epoch: 68, Loss: 0.131391
# Epoch: 69, Loss: 0.094105
# Epoch: 70, Loss: 0.052197
# Epoch: 71, Loss: 0.115692
# Epoch: 72, Loss: 0.075527
# Epoch: 73, Loss: 0.173164
# Epoch: 74, Loss: 0.088908
# Epoch: 75, Loss: 0.132034
# Epoch: 76, Loss: 0.143040
# Epoch: 77, Loss: 0.082845
# Epoch: 78, Loss: 0.069644
# Epoch: 79, Loss: 0.080694
# Epoch: 80, Loss: 0.074238
# Epoch: 81, Loss: 0.057201
# Epoch: 82, Loss: 0.061448
# Epoch: 83, Loss: 0.087552
# Epoch: 84, Loss: 0.145612
# Epoch: 85, Loss: 0.047745
# Epoch: 86, Loss: 0.075260
# Epoch: 87, Loss: 0.064548
# Epoch: 88, Loss: 0.043033
# Epoch: 89, Loss: 0.039708
# Epoch: 90, Loss: 0.063168
# Epoch: 91, Loss: 0.014961
# Epoch: 92, Loss: 0.023704
# Epoch: 93, Loss: 0.053019
# Epoch: 94, Loss: 0.054008
# Epoch: 95, Loss: 0.098904
# Epoch: 96, Loss: 0.028738
# Epoch: 97, Loss: 0.043777
# Epoch: 98, Loss: 0.044313
# Epoch: 99, Loss: 0.058320

# %%
# Calculate and print accuracies
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64, shuffle=False)
correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
print("Train Accuracy: %f" % (correct / total))

val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64, shuffle=False)
correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in val_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
print("Validation Accuracy: %f" % (correct / total))
# Out:
# Train Accuracy: 0.999340
# Validation Accuracy: 0.469100

# %% [markdown]
# # **Problem 2b: 10 classes in CIFAR-10, SGD, three hidden layers**

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64, shuffle=True)

model = nn.Sequential(
            nn.Linear(3072, 512),
            nn.Tanh(),
            nn.Linear(512, 1024),
            nn.Tanh(),
            nn.Linear(1024, 256),
            nn.Tanh(),
            nn.Linear(256, 10),
            nn.LogSoftmax(dim=1)
          ).to(device)

learning_rate = 1e-2
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
loss_fn = nn.NLLLoss()
n_epochs = 300

for epoch in range(n_epochs):
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        loss = loss_fn(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print("Epoch: %d, Loss: %f" % (epoch, float(loss)))
# Out:
# Epoch: 0, Loss: 1.697552
# Epoch: 1, Loss: 1.831883
# Epoch: 2, Loss: 1.536923
# Epoch: 3, Loss: 1.457405
# Epoch: 4, Loss: 1.489388
# Epoch: 5, Loss: 1.731159
# Epoch: 6, Loss: 1.334795
# Epoch: 7, Loss: 1.665372
# Epoch: 8, Loss: 0.982141
# Epoch: 9, Loss: 1.410920
# Epoch: 10, Loss: 1.415032
# Epoch: 11, Loss: 1.032603
# Epoch: 12, Loss: 1.155181
# Epoch: 13, Loss: 0.998427
# Epoch: 14, Loss: 1.266021
# Epoch: 15, Loss: 1.614120
# Epoch: 16, Loss: 1.301897
# Epoch: 17, Loss: 1.098426
# Epoch: 18, Loss: 1.247498
# Epoch: 19, Loss: 0.529229
# Epoch: 20, Loss: 0.635562
# Epoch: 21, Loss: 0.690473
# Epoch: 22, Loss: 1.390990
# Epoch: 23, Loss: 0.626261
# Epoch: 24, Loss: 0.626870
# Epoch: 25, Loss: 0.590364
# Epoch: 26, Loss: 0.537547
# Epoch: 27, Loss: 0.697929
# Epoch: 28, Loss: 0.357656
# Epoch: 29, Loss: 0.658323
# Epoch: 30, Loss: 0.496363
# Epoch: 31, Loss: 0.676070
# Epoch: 32, Loss: 0.977613
# Epoch: 33, Loss: 0.541223
# Epoch: 34, Loss: 0.384449
# Epoch: 35, Loss: 0.186993
# Epoch: 36, Loss: 0.236725
# Epoch: 37, Loss: 0.245368
# Epoch: 38, Loss: 0.230471
# Epoch: 39, Loss: 0.079308
# Epoch: 40, Loss: 0.336922
# Epoch: 41, Loss: 0.083896
# Epoch: 42, Loss: 0.158286
# Epoch: 43, Loss: 0.216497
# Epoch: 44, Loss: 0.099026
# Epoch: 45, Loss: 0.083948
# Epoch: 46, Loss: 0.054640
# Epoch: 47, Loss: 0.067726
# Epoch: 48, Loss: 0.021918
# Epoch: 49, Loss: 0.589043
# Epoch: 50, Loss: 0.009918
# Epoch: 51, Loss: 0.387348
# Epoch: 52, Loss: 0.072066
# Epoch: 53, Loss: 0.082188
# Epoch: 54, Loss: 0.249772
# Epoch: 55, Loss: 0.011328
# Epoch: 56, Loss: 0.047288
# Epoch: 57, Loss: 0.010090
# Epoch: 58, Loss: 0.044493
# Epoch: 59, Loss: 0.048934
# Epoch: 60, Loss: 0.008228
# Epoch: 61, Loss: 0.022024
# Epoch: 62, Loss: 0.145171
# Epoch: 63, Loss: 0.097166
# Epoch: 64, Loss: 0.004633
# Epoch: 65, Loss: 0.005528
# Epoch: 66, Loss: 0.003664
# Epoch: 67, Loss: 0.029602
# Epoch: 68, Loss: 0.236850
# Epoch: 69, Loss: 0.022342
# Epoch: 70, Loss: 0.013257
# Epoch: 71, Loss: 0.005135
# Epoch: 72, Loss: 0.002812
# Epoch: 73, Loss: 0.004198
# Epoch: 74, Loss: 0.003280
# Epoch: 75, Loss: 0.002014
# Epoch: 76, Loss: 0.009760
# Epoch: 77, Loss: 0.002742
# Epoch: 78, Loss: 0.002409
# Epoch: 79, Loss: 0.003932
# Epoch: 80, Loss: 0.005489
# Epoch: 81, Loss: 0.005068
# Epoch: 82, Loss: 0.001673
# Epoch: 83, Loss: 0.002008
# Epoch: 84, Loss: 0.003350
# Epoch: 85, Loss: 0.002153
# Epoch: 86, Loss: 0.003777
# Epoch: 87, Loss: 0.002532
# Epoch: 88, Loss: 0.001568
# Epoch: 89, Loss: 0.004798
# Epoch: 90, Loss: 0.001250
# Epoch: 91, Loss: 0.001589
# Epoch: 92, Loss: 0.001963
# Epoch: 93, Loss: 0.000727
# Epoch: 94, Loss: 0.001559
# Epoch: 95, Loss: 0.001126
# Epoch: 96, Loss: 0.002329
# Epoch: 97, Loss: 0.001292
# Epoch: 98, Loss: 0.001715
# Epoch: 99, Loss: 0.002336
# Epoch: 100, Loss: 0.001968
# Epoch: 101, Loss: 0.000640
# Epoch: 102, Loss: 0.001373
# Epoch: 103, Loss: 0.001068
# Epoch: 104, Loss: 0.000741
# Epoch: 105, Loss: 0.000805
# Epoch: 106, Loss: 0.000723
# Epoch: 107, Loss: 0.001205
# Epoch: 108, Loss: 0.000662
# Epoch: 109, Loss: 0.001188
# Epoch: 110, Loss: 0.000568
# Epoch: 111, Loss: 0.000391
# Epoch: 112, Loss: 0.001197
# Epoch: 113, Loss: 0.001357
# Epoch: 114, Loss: 0.000929
# Epoch: 115, Loss: 0.001289
# Epoch: 116, Loss: 0.000295
# Epoch: 117, Loss: 0.000443
# Epoch: 118, Loss: 0.001806
# Epoch: 119, Loss: 0.000996
# Epoch: 120, Loss: 0.000487
# Epoch: 121, Loss: 0.001645
# Epoch: 122, Loss: 0.000570
# Epoch: 123, Loss: 0.000502
# Epoch: 124, Loss: 0.000879
# Epoch: 125, Loss: 0.001542
# Epoch: 126, Loss: 0.000648
# Epoch: 127, Loss: 0.000714
# Epoch: 128, Loss: 0.000595
# Epoch: 129, Loss: 0.000324
# Epoch: 130, Loss: 0.000439
# Epoch: 131, Loss: 0.001111
# Epoch: 132, Loss: 0.000923
# Epoch: 133, Loss: 0.000573
# Epoch: 134, Loss: 0.000426
# Epoch: 135, Loss: 0.000635
# Epoch: 136, Loss: 0.000732
# Epoch: 137, Loss: 0.000866
# Epoch: 138, Loss: 0.000654
# Epoch: 139, Loss: 0.001190
# Epoch: 140, Loss: 0.000673
# Epoch: 141, Loss: 0.000637
# Epoch: 142, Loss: 0.000741
# Epoch: 143, Loss: 0.001403
# Epoch: 144, Loss: 0.000594
# Epoch: 145, Loss: 0.001096
# Epoch: 146, Loss: 0.000742
# Epoch: 147, Loss: 0.000581
# Epoch: 148, Loss: 0.000683
# Epoch: 149, Loss: 0.000670
# Epoch: 150, Loss: 0.000857
# Epoch: 151, Loss: 0.000739
# Epoch: 152, Loss: 0.000788
# Epoch: 153, Loss: 0.001526
# Epoch: 154, Loss: 0.000536
# Epoch: 155, Loss: 0.000184
# Epoch: 156, Loss: 0.000721
# Epoch: 157, Loss: 0.000626
# Epoch: 158, Loss: 0.000792
# Epoch: 159, Loss: 0.000532
# Epoch: 160, Loss: 0.000392
# Epoch: 161, Loss: 0.000587
# Epoch: 162, Loss: 0.000758
# Epoch: 163, Loss: 0.000812
# Epoch: 164, Loss: 0.000731
# Epoch: 165, Loss: 0.000385
# Epoch: 166, Loss: 0.000648
# Epoch: 167, Loss: 0.000788
# Epoch: 168, Loss: 0.000576
# Epoch: 169, Loss: 0.000493
# Epoch: 170, Loss: 0.000296
# Epoch: 171, Loss: 0.000459
# Epoch: 172, Loss: 0.000239
# Epoch: 173, Loss: 0.000847
# Epoch: 174, Loss: 0.000274
# Epoch: 175, Loss: 0.000647
# Epoch: 176, Loss: 0.000477
# Epoch: 177, Loss: 0.000368
# Epoch: 178, Loss: 0.000292
# Epoch: 179, Loss: 0.000326
# Epoch: 180, Loss: 0.000306
# Epoch: 181, Loss: 0.000309
# Epoch: 182, Loss: 0.000571
# Epoch: 183, Loss: 0.000305
# Epoch: 184, Loss: 0.000366
# Epoch: 185, Loss: 0.000422
# Epoch: 186, Loss: 0.000358
# Epoch: 187, Loss: 0.000493
# Epoch: 188, Loss: 0.000226
# Epoch: 189, Loss: 0.000271
# Epoch: 190, Loss: 0.000458
# Epoch: 191, Loss: 0.000735
# Epoch: 192, Loss: 0.000310
# Epoch: 193, Loss: 0.000410
# Epoch: 194, Loss: 0.000424
# Epoch: 195, Loss: 0.000628
# Epoch: 196, Loss: 0.000440
# Epoch: 197, Loss: 0.000446
# Epoch: 198, Loss: 0.000302
# Epoch: 199, Loss: 0.000570
# Epoch: 200, Loss: 0.000612
# Epoch: 201, Loss: 0.000776
# Epoch: 202, Loss: 0.000942
# Epoch: 203, Loss: 0.000436
# Epoch: 204, Loss: 0.000276
# Epoch: 205, Loss: 0.000329
# Epoch: 206, Loss: 0.000448
# Epoch: 207, Loss: 0.000386
# Epoch: 208, Loss: 0.000352
# Epoch: 209, Loss: 0.000427
# Epoch: 210, Loss: 0.000437
# Epoch: 211, Loss: 0.000401
# Epoch: 212, Loss: 0.000354
# Epoch: 213, Loss: 0.000495
# Epoch: 214, Loss: 0.000197
# Epoch: 215, Loss: 0.000262
# Epoch: 216, Loss: 0.000543
# Epoch: 217, Loss: 0.000363
# Epoch: 218, Loss: 0.000168
# Epoch: 219, Loss: 0.000257
# Epoch: 220, Loss: 0.000164
# Epoch: 221, Loss: 0.000618
# Epoch: 222, Loss: 0.000470
# Epoch: 223, Loss: 0.000316
# Epoch: 224, Loss: 0.000236
# Epoch: 225, Loss: 0.000330
# Epoch: 226, Loss: 0.000697
# Epoch: 227, Loss: 0.000382
# Epoch: 228, Loss: 0.000318
# Epoch: 229, Loss: 0.000238
# Epoch: 230, Loss: 0.000365
# Epoch: 231, Loss: 0.000205
# Epoch: 232, Loss: 0.000284
# Epoch: 233, Loss: 0.000464
# Epoch: 234, Loss: 0.000327
# Epoch: 235, Loss: 0.000431
# Epoch: 236, Loss: 0.000194
# Epoch: 237, Loss: 0.000509
# Epoch: 238, Loss: 0.000371
# Epoch: 239, Loss: 0.000295
# Epoch: 240, Loss: 0.000318
# Epoch: 241, Loss: 0.000516
# Epoch: 242, Loss: 0.000417
# Epoch: 243, Loss: 0.000283
# Epoch: 244, Loss: 0.000269
# Epoch: 245, Loss: 0.000356
# Epoch: 246, Loss: 0.000393
# Epoch: 247, Loss: 0.000133
# Epoch: 248, Loss: 0.000200
# Epoch: 249, Loss: 0.000335
# Epoch: 250, Loss: 0.000341
# Epoch: 251, Loss: 0.000175
# Epoch: 252, Loss: 0.000252
# Epoch: 253, Loss: 0.000259
# Epoch: 254, Loss: 0.000311
# Epoch: 255, Loss: 0.000156
# Epoch: 256, Loss: 0.000146
# Epoch: 257, Loss: 0.000319
# Epoch: 258, Loss: 0.000203
# Epoch: 259, Loss: 0.000312
# Epoch: 260, Loss: 0.000280
# Epoch: 261, Loss: 0.000336
# Epoch: 262, Loss: 0.000292
# Epoch: 263, Loss: 0.000097
# Epoch: 264, Loss: 0.000414
# Epoch: 265, Loss: 0.000173
# Epoch: 266, Loss: 0.000273
# Epoch: 267, Loss: 0.000237
# Epoch: 268, Loss: 0.000359
# Epoch: 269, Loss: 0.000244
# Epoch: 270, Loss: 0.000534
# Epoch: 271, Loss: 0.000184
# Epoch: 272, Loss: 0.000392
# Epoch: 273, Loss: 0.000247
# Epoch: 274, Loss: 0.000313
# Epoch: 275, Loss: 0.000116
# Epoch: 276, Loss: 0.000227
# Epoch: 277, Loss: 0.000430
# Epoch: 278, Loss: 0.000408
# Epoch: 279, Loss: 0.000206
# Epoch: 280, Loss: 0.000133
# Epoch: 281, Loss: 0.000210
# Epoch: 282, Loss: 0.000198
# Epoch: 283, Loss: 0.000304
# Epoch: 284, Loss: 0.000362
# Epoch: 285, Loss: 0.000402
# Epoch: 286, Loss: 0.000159
# Epoch: 287, Loss: 0.000072
# Epoch: 288, Loss: 0.000132
# Epoch: 289, Loss: 0.000153
# Epoch: 290, Loss: 0.000324
# Epoch: 291, Loss: 0.000956
# Epoch: 292, Loss: 0.000167
# Epoch: 293, Loss: 0.000171
# Epoch: 294, Loss: 0.000229
# Epoch: 295, Loss: 0.000278
# Epoch: 296, Loss: 0.000291
# Epoch: 297, Loss: 0.000469
# Epoch: 298, Loss: 0.000328
# Epoch: 299, Loss: 0.000289

# %%
# Calculate and print accuracies
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64, shuffle=False)
correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
print("Train Accuracy: %f" % (correct / total))

val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64, shuffle=False)
correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in val_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
print("Validation Accuracy: %f" % (correct / total))
# Out:
# Train Accuracy: 1.000000
# Validation Accuracy: 0.450200
